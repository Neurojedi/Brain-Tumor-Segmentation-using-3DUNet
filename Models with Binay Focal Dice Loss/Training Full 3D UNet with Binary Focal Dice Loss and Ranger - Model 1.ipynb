# %% [markdown]
# # Training Full 3D UNet with Binary Focal Dice Loss and Ranger - Model 1
#
# This notebook contains the code that I used to train the 3D U-Net model from scratch using the Binary Focal Dice Loss function and the Ranger optimizer.

# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install segmentation_models==1.0.1 # I deleted the output of this cell since it is irrelevant.
# !pip install nilearn
# !pip install tensorflow-addons

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-1bb7bb66-d1a2-1cf9-704e-7c22560688f0)

# %%
# utils
import h5py
import os
import json
from util import load_case
from dataprocessing import get_sub_volume, standardize, CreateSubVolumes, get_config
from losses import  dice_coefficient
import segmentation_models as sm
import util

# neural imaging
import nilearn as nl
import nibabel as nib
import numpy as np

# ml libs
import keras
import keras.backend as K
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from keras.callbacks import Callback, ModelCheckpoint

#Plots
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading and Pre-processing the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xvf "/content/drive/MyDrive/Task01_BrainTumour.tar" -C "/content/"

# %% [markdown]
# The `CreateSubVolumes()` function creates a new folder named **subvolumes** and adds subvolumes to it.

# %%
jsonfile_path="/content/Task01_BrainTumour/dataset.json"
outputpath="/content/subvolumes/"

# %%
CreateSubVolumes(jsonfile_path,outputpath)
# Out:
# Creating the training list...
# 100%|██████████| 484/484 [00:00<00:00, 595146.04it/s]
# Creating the sub-volumes...
# 100%|██████████| 484/484 [18:33<00:00,  2.30s/it]
# For 84 files, could not find a sub-volume after trying 1000 times.

# %% [markdown]
# In the following code, I create a config file and split the data into train and validation sets.

# %%
h5_path="/content/subvolumes"
get_config(h5_path,0.20) # %20 of the data is used for validation.
with open("/content/config.json") as json_file:
    config = json.load(json_file)

# %%
# Get generators for training and validation sets
train_generator = util.VolumeDataGenerator(config["train"], "/content/subvolumes/", batch_size=6, dim=(160, 160, 16), verbose=0)
valid_generator = util.VolumeDataGenerator(config["valid"], "/content/subvolumes/", batch_size=6, dim=(160, 160, 16), verbose=0)
train_generator

# %% [markdown]
# Let's check the shapes.

# %%
data = next(iter(train_generator))
data[0].shape, data[1].shape
# Out:
# ((6, 4, 160, 160, 16), (6, 3, 160, 160, 16))

# %% [markdown]
# ## Training the Models
#
# Now, I can finally start training the model. I will train three models using the `sm.losses.binary_focal_dice_loss()` with 0.001 - 0.00001, 0.0001 - 0.000001, and 0.00001 - 0.0000001 learning rate ranges.

# %% [markdown]
# ### Model 1 : initial_lr = 0.001 and final_lr = 0.00001

# %%
tf.keras.backend.clear_session()
model_bfocaldice = util.unet_model_3d(loss_function=sm.losses.binary_focal_dice_loss, initial_learning_rate=0.001, final_learning_rate=0.00001,  deconvolution=False, 
                               batch_normalization=False, metrics=['accuracy',dice_coefficient, sm.metrics.IOUScore(threshold=0.5)])

# %%
checkpoint = ModelCheckpoint(
    'fullmodel1_bfocaldice_ranger1.h5', 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'

)

history=model_bfocaldice.fit_generator(generator=train_generator,
        epochs=40,
        validation_data=valid_generator,
        callbacks=[checkpoint])

# %%
sns.set_theme()
pd.DataFrame(history.history).plot(figsize=(15, 10))
plt.xlabel("Epoch")
plt.legend(loc="best")
plt.show()

# %%
# !cp -r '/content/fullmodel1_bfocaldice_ranger1.h5' /content/drive/MyDrive/ # Saving the weights.

# %% [markdown]
# ### Model 2 : initial_lr = 0.0001 and final_lr = 0.000001

# %%
tf.keras.backend.clear_session()
model_bfocaldice2 = util.unet_model_3d(loss_function=sm.losses.binary_focal_dice_loss, initial_learning_rate=0.0001, final_learning_rate=0.000001,  deconvolution=False, 
                               batch_normalization=False, metrics=['accuracy',dice_coefficient,sm.metrics.IOUScore(threshold=0.5)])

# %%
checkpoint2 = ModelCheckpoint(
    'fullmodel1_bfocaldice_ranger2.h5', 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'

)

history2=model_bfocaldice2.fit_generator(generator=train_generator,
        epochs=40,
        validation_data=valid_generator,
        callbacks=[checkpoint2])

# %%
sns.set_theme()
pd.DataFrame(history2.history).plot(figsize=(15, 10))
plt.xlabel("Epoch")
plt.legend(loc="best")
plt.show()

# %%
# !cp -r '/content/fullmodel1_bfocaldice_ranger2.h5' /content/drive/MyDrive/ # Saving the weights.

# %% [markdown]
# ### Model 3 : initial_lr = 0.00001 and final_lr = 0.0000001

# %%
tf.keras.backend.clear_session()
model_bfocaldice3 = util.unet_model_3d(loss_function=sm.losses.binary_focal_dice_loss, initial_learning_rate=0.00001, final_learning_rate=0.0000001,  deconvolution=False, 
                               batch_normalization=False, metrics=['accuracy',dice_coefficient,sm.metrics.IOUScore(threshold=0.5)])

# %%
checkpoint3 = ModelCheckpoint(
    'fullmodel1_bfocaldice_ranger3.h5', 
    monitor='val_loss', 
    verbose=1,  save_weights_only=False,
    mode='auto'
)

history3=model_bfocaldice3.fit_generator(generator=train_generator,
        epochs=40,
        validation_data=valid_generator,
        callbacks=[checkpoint3])

# %%
sns.set_theme()
pd.DataFrame(history3.history).plot(figsize=(15, 10))
plt.xlabel("Epoch")
plt.legend(loc="best")
plt.show()

# %%
# !cp -r '/content/fullmodel1_bfocaldice_ranger3.h5' /content/drive/MyDrive/ # Saving the weights.
